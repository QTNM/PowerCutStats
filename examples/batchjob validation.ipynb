# %% [markdown]
# # Simulated Event Data

# %% [markdown]
# In this notebook, we're collecting the data from both the Harmonic and Bathtub simulations and saving it using Pandas in a `.csv` file.

# %%
import sys
sys.path.append("../")

from __init__ import *
from data_tools import *
from testing import *

# %% [markdown]
# First up is locating the directory, for this to work on your local machine, change the `path_to_dir' to wherever the files are stored (they aren't stored in this github repo due to storage limitations). This is done to first generate the list of files.
#
# You'll also need to provide a `path_prefix` to point to the directory from the current notebook's position.
#
# The for loops then should provide a `bathtub_sim_list` and `harmonic_sim_list` which are the relative paths to all the simulated files.

# %%
path_to_dir = '/Users/nathan/Desktop/BatchCreatedFiles/' # Path to data

harmonic = 'Harmonic/' # Harmonic Prefix
bathtub = 'Bathtub/' # Bathtub Prefix
# shallowtrap = 'ShallowTrap/' # ShallowTrap Prefix

path_to_harmonic = path_to_dir + harmonic # Path to Harmonic Data
path_to_bathtub = path_to_dir + bathtub # Path to Bathtub Data
# path_to_shallowtrap = path_to_dir + shallowtrap # Path to ShallowTrap Data  

harmonic_list = glob.glob(path_to_harmonic + '/**/*.h5', recursive=True) # List of Harmonic Files
harmonic_sim_list = [] # New List of Harmonic Files

path_prefix = '../../../../' # Path Prefix

for f in harmonic_list: # Iterate through list of Harmonic Files

    suffix = f.split('nathan/')[-1] # Get the suffix of the file
    true_path = path_prefix + suffix # Get the true path of the file
    harmonic_sim_list.append(true_path) # Append the true path to the new list
    
bathtub_list = glob.glob(path_to_bathtub + '/**/*.h5', recursive=True)
bathtub_sim_list = []

for f in bathtub_list:
    suffix = f.split('nathan/')[-1]
    true_path = path_prefix + suffix # Get the true path of the file
    bathtub_sim_list.append(true_path)
    
# shallowtrap_list = glob.glob(path_to_shallowtrap + '/**/*.h5', recursive=True)
# shallowtrap_sim_list = []

# for f in shallowtrap_list:
#     suffix = f.split('nathan/')[-1]
#     true_path = path_prefix + suffix # Get the true path of the file
#     shallowtrap_sim_list.append(true_path)

# %%
# np.savetxt('../data/simulations_truth/harmonic_scatter_filenames.csv', np.array(harmonic_sim_list))

HSL = pd.DataFrame(harmonic_sim_list)
print(len(harmonic_sim_list))


# HSL.to_csv('../data/simulations_truth/harmonic_scatter_filenames.csv', index=False)
# np.array(harmonic_sim_list, dtype=str)
# Out:
# 3713

# %%
signal_strings, b, data = get_attributes(harmonic_sim_list[0], full_path=True)

print(signal_strings)
print(b)
print(data)

signal = get_signal(harmonic_sim_list[0], signal_strings[0])


plt.specgram(signal, NFFT=1024, Fs=1e9, noverlap=900)
plt.show()
# Out:
# ['signal1', 'signal2']
# ['B_bkg [Tesla]', 'Cyclotron frequency [Hertz]', 'Downmixed cyclotron frequency [Hertz]', 'Energy [eV]', 'LO frequency [Hertz]', 'Pitch angle [degrees]', 'Starting position [metres]', 'Starting velocity [metres/second]', 'Time step [seconds]', 'Waveguide impedance [Ohms]', 'i_coil [Amps]', 'r_coil [metres]', 'r_wg [metres]']
# [[1.0048571427712552, 27010452267.737232, 118614666.93206406, 18575.0, 26891837600.80517, 89.9, array([0.0009, 0.    , 0.    ]), array([-74088941.24098547, -26553174.5069338 ,   -137363.67554547]), 1e-09, 496.01386174924346, 154.60765618550025, 0.02, 0.005], [1.0048571427712552, 27010452267.737232, 0.0, 18575.0, 26891837600.80517, 89.9, array([0.0009, 0.    , 0.    ]), array([-74088941.24098547, -26553174.5069338 ,   -137363.67554547]), 1e-09, 496.01386174924346, 154.60765618550025, 0.02, 0.005]]

# %% [markdown]
# Now that we have `bathtub_sim_list` and `harmonic_sim_list` we need to set up the structure of the data frame or table that we're going to be storing the data in.
#
# We have
# - `frame_strings`: The column headers describing the different variables of each simulated event
# - `signal_strings`: The column headers describing the different signals of each simulated event (different polarisations 'signal1' and 'signal2')
# - `data`: The truth data from the simulated event
# - `vars`: The variables of the simulated event with associated data
# - `frame`: The data frame of all the simulated events
#
# with some other less important variables scattered throughout. Below is how the scheme works and is implemented into `data_tools.py`.

# %%
frame_strings = [           'File_name',
                               'signal',
                                 'trap',
              'Axial Frequency [Hertz]',     
                        'B_bkg [Tesla]',
                   'Gas density [m^-3]',
                 'LO frequency [Hertz]',
                'Pitch angle [degrees]',
                          'Energy [eV]',
          'Cyclotron frequency [Hertz]',
'Downmixed cyclotron frequency [Hertz]',
                       'Time [seconds]', 
                  'Time step [seconds]',
                        'i_coil [Amps]',
                      'r_coil [metres]',
                        'r_wg [metres]',
         'Starting x position [metres]',
         'Starting y position [metres]',
         'Maxmimum z position [metres]',
         'Starting z position [metres]',
         ]


verbose=True
save_file=False

for i, f in enumerate(harmonic_sim_list):
    signal_strings, b, data = get_attributes(f, full_path=True)
    filename = f.split('/')[-1]
    trap_type = f.split('/')[-2]
    
    # print(signal_strings[0])
    # print(b)
    # print(data[0][0])
    # print(filename)
    # print(trap_type)
    

    
    vars = {
        'File_name': filename,
        'signal': signal_strings[0],
        'trap': trap_type,
        'f_axial': data[0][0],
        'B_bkg': data[0][1],
        'Gas_p': data[0][2],
        'f_lo': data[0][3],
        'pitch_angle': data[0][4],
        'energy': data[0][5],
        'f_cyc': data[0][6],
        'f_cyc_d': data[0][7],
        't': data[0][8],
        'dt': data[0][9],
        'i_coil': data[0][10],
        'r_coil': data[0][11],
        'r_wg': data[0][12],
        'r_x': data[0][14],
        'r_y': data[0][15],
        'r_z_max': data[0][16],
        'r_z': data[0][17],
        
    }
    
    new_frame = pd.DataFrame(vars)
    
    if i == 0:
      frame = pd.DataFrame(vars)
    
    else:
      frame = pd.concat([frame, new_frame], axis=0)
    
    if verbose and i % 100 == 0:
        print(str(i) + ' files processed')

frame.columns = frame_strings

if save_file:
  frame.to_csv('../data/simulations_truth/harmonic_scatters.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [6], line 57
#      30 trap_type = f.split('/')[-2]
#      32 # print(signal_strings[0])
#      33 # print(b)
#      34 # print(data[0][0])
#      35 # print(filename)
#      36 # print(trap_type)
#      40 vars = {
#      41     'File_name': filename,
#      42     'signal': signal_strings[0],
#      43     'trap': trap_type,
#      44     'f_axial': data[0][0],
#      45     'B_bkg': data[0][1],
#      46     'Gas_p': data[0][2],
#      47     'f_lo': data[0][3],
#      48     'pitch_angle': data[0][4],
#      49     'energy': data[0][5],
#      50     'f_cyc': data[0][6],
#      51     'f_cyc_d': data[0][7],
#      52     't': data[0][8],
#      53     'dt': data[0][9],
#      54     'i_coil': data[0][10],
#      55     'r_coil': data[0][11],
#      56     'r_wg': data[0][12],
# ---> 57     'r_x': data[0][14],
#      58     'r_y': data[0][15],
#      59     'r_z_max': data[0][16],
#      60     'r_z': data[0][17],
#      61
#      62 }
#      64 new_frame = pd.DataFrame(vars)
#      66 if i == 0:
#
# IndexError: list index out of range

# %%
harmonic_frame = frame

# %% [markdown]
# This time, we'll use the `data_tools.py` file to store the functions and classes that we'll be using to generate the data.

# %%
savefile = '../data/simulations_truth/bathtub.csv'

bathtub_frame = get_truth_data(bathtub_sim_list, verbose=False, savefile=False)

# %%
path_to_dir_1T = '/Users/nathan/Desktop/1Tesla/v1/' # Path to data

harmonic_1T = 'Harmonic/' # Harmonic Prefix
bathtub_1T = 'Bathtub/' # Bathtub Prefix

path_to_harmonic_1T = path_to_dir_1T + harmonic_1T # Path to Harmonic Data
path_to_bathtub_1T = path_to_dir_1T + bathtub_1T # Path to Bathtub Data

harmonic_list_1T = glob.glob(path_to_harmonic_1T + '/**/*.h5', recursive=True) # List of Harmonic Files
harmonic_sim_list_1T = [] # New List of Harmonic Files

path_prefix = '../../../../' # Path Prefix

for f in harmonic_list_1T: # Iterate through list of Harmonic Files

    suffix = f.split('nathan/')[-1] # Get the suffix of the file
    true_path_1T = path_prefix + suffix # Get the true path of the file
    harmonic_sim_list_1T.append(true_path_1T) # Append the true path to the new list
    
bathtub_list_1T = glob.glob(path_to_bathtub_1T + '/**/*.h5', recursive=True)
bathtub_sim_list_1T = []

for f in bathtub_list_1T:
    suffix = f.split('nathan/')[-1]
    true_path_1T = '../../../../' + suffix
    bathtub_sim_list_1T.append(true_path_1T)

# %%
savefile = '../data/simulations_truth/bathtub_1T.csv'

bathtub_frame_1T = get_truth_data(bathtub_sim_list_1T, verbose=False, savefile=savefile)

savefile = '../data/simulations_truth/harmonic_1T.csv'

harmonic_frame_1T = get_truth_data(harmonic_sim_list_1T, verbose=False, savefile=savefile)

# %%
# file = path + '90harmonic.h5'


file = harmonic_sim_list[0]
index = 0

# harmonic_sim_list

for i in range(10):
    file = harmonic_sim_list[i]

    strings, attributes, attributes_values = get_attributes(file, full_path=True)

    print(strings)
    print(attributes)
    print(attributes_values[0][7])


    impedance = attributes_values[index][10]

    print(impedance)

    print(strings[index], "has a", attributes[10], 'equal to', impedance, 'Ohms')

    signal = get_signal(file, strings[index])

    # no_samples = 40960 # For a 40.96 us time slice


    # Plot a spectrogram of the signal

    plt.specgram(signal, NFFT=1024, Fs=1e9, noverlap=900)
    plt.ylabel('Frequency [Hz]')
    plt.xlabel('Time [s]')
    plt.colorbar()

    for i in range(len(attributes_values[0][7])):
        plt.scatter(attributes_values[index][8][i],  attributes_values[index][7][i], color='r')


    plt.show()



# signal_fft = np.fft.rfft(signal[:no_samples]) * 16 # Account for power issues, 16 is a scaling factor

# print('Time slice is', no_samples * 1e-9 * 1e6, ' micro seconds')
# print('With a total number of ', len(np.abs(signal_fft)), 'Bins')

# # Noise FFT
# noise = generate_noise(5, no_samples, resistance = impedance)

# noise_fft = np.fft.rfft(noise)

# plt.plot(np.abs(noise_fft))
# plt.plot(np.abs(signal_fft))
# plt.ylabel('FFT Amplitude (V)')
# plt.xlabel('Frequency')
# plt.show()

# # n_fft = np.abs(noise_fft)**2
# # s_fft = np.abs(signal_fft)**2


# # plt.plot(s_fft/impedance)
# # plt.plot(n_fft/impedance)
# # plt.ylabel('Power (A^2/R)')
# # plt.xlabel('Frequency')
# # plt.show()


# sig_val = np.max(abs(signal_fft))
# print(np.max(signal_fft))
# Out:
# ['signal1', 'signal2']
# ['Axial F [Hertz]', 'B_bkg [Tesla]', 'Gas density [m^-3]', 'LO frequency [Hertz]', 'Pitch angle [degrees]', 'Start E [eV]', 'Start F [Hertz]', 'Start F, downmixed [Hertz]', 'Time [seconds]', 'Time step [seconds]', 'Waveguide impedance [Ohms]', 'i_coil [Amps]', 'r_coil [metres]', 'r_wg [metres]', 'x_start [metres]', 'y_start [metres]', 'z_max [metres]', 'z_start [metres]']
# [2.60790303e+08 2.65015315e+08 2.69160217e+08 2.71605441e+08
#  2.76185386e+08 2.90166053e+08 3.37002435e+08]
# 594.9123724765152
# signal1 has a Waveguide impedance [Ohms] equal to 594.9123724765152 Ohms
# ['signal1', 'signal2']
# ['Axial F [Hertz]', 'B_bkg [Tesla]', 'Gas density [m^-3]', 'LO frequency [Hertz]', 'Pitch angle [degrees]', 'Start E [eV]', 'Start F [Hertz]', 'Start F, downmixed [Hertz]', 'Time [seconds]', 'Time step [seconds]', 'Waveguide impedance [Ohms]', 'i_coil [Amps]', 'r_coil [metres]', 'r_wg [metres]', 'x_start [metres]', 'y_start [metres]', 'z_max [metres]', 'z_start [metres]']
# [2.79749618e+08 2.82411528e+08 3.04037260e+08 3.04426688e+08
#  3.04933493e+08 3.35807513e+08 3.58149127e+08]
# 594.0251459031015
# signal1 has a Waveguide impedance [Ohms] equal to 594.0251459031015 Ohms
# ['signal1', 'signal2']
# ['Axial F [Hertz]', 'B_bkg [Tesla]', 'Gas density [m^-3]', 'LO frequency [Hertz]', 'Pitch angle [degrees]', 'Start E [eV]', 'Start F [Hertz]', 'Start F, downmixed [Hertz]', 'Time [seconds]', 'Time step [seconds]', 'Waveguide impedance [Ohms]', 'i_coil [Amps]', 'r_coil [metres]', 'r_wg [metres]', 'x_start [metres]', 'y_start [metres]', 'z_max [metres]', 'z_start [metres]']
# [2.97692058e+08 3.61709964e+08]
# 593.1915858301588
# signal1 has a Waveguide impedance [Ohms] equal to 593.1915858301588 Ohms
# ['signal1', 'signal2']
# ['Axial F [Hertz]', 'B_bkg [Tesla]', 'Gas density [m^-3]', 'LO frequency [Hertz]', 'Pitch angle [degrees]', 'Start E [eV]', 'Start F [Hertz]', 'Start F, downmixed [Hertz]', 'Time [seconds]', 'Time step [seconds]', 'Waveguide impedance [Ohms]', 'i_coil [Amps]', 'r_coil [metres]', 'r_wg [metres]', 'x_start [metres]', 'y_start [metres]', 'z_max [metres]', 'z_start [metres]']
# [2.69311575e+08 2.73407426e+08 2.72697574e+08 2.88714644e+08
#  3.13640134e+08 3.09037275e+08 3.50746970e+08]
# 594.5127866299721
# signal1 has a Waveguide impedance [Ohms] equal to 594.5127866299721 Ohms
# ['signal1', 'signal2']
# ['Axial F [Hertz]', 'B_bkg [Tesla]', 'Gas density [m^-3]', 'LO frequency [Hertz]', 'Pitch angle [degrees]', 'Start E [eV]', 'Start F [Hertz]', 'Start F, downmixed [Hertz]', 'Time [seconds]', 'Time step [seconds]', 'Waveguide impedance [Ohms]', 'i_coil [Amps]', 'r_coil [metres]', 'r_wg [metres]', 'x_start [metres]', 'y_start [metres]', 'z_max [metres]', 'z_start [metres]']
# [3.22587703e+08 3.25728709e+08 3.21491808e+08 2.87200396e+08
#  2.83405250e+08 3.17015229e+08 3.19466710e+08 3.58764817e+08]
# 592.0446707714223
# signal1 has a Waveguide impedance [Ohms] equal to 592.0446707714223 Ohms
# ['signal1', 'signal2']
# ['Axial F [Hertz]', 'B_bkg [Tesla]', 'Gas density [m^-3]', 'LO frequency [Hertz]', 'Pitch angle [degrees]', 'Start E [eV]', 'Start F [Hertz]', 'Start F, downmixed [Hertz]', 'Time [seconds]', 'Time step [seconds]', 'Waveguide impedance [Ohms]', 'i_coil [Amps]', 'r_coil [metres]', 'r_wg [metres]', 'x_start [metres]', 'y_start [metres]', 'z_max [metres]', 'z_start [metres]']
# [2.89147724e+08 2.88305923e+08 3.43270035e+08 3.42584100e+08
#  3.34783187e+08 3.72554839e+08]
# 593.5878006068257
# signal1 has a Waveguide impedance [Ohms] equal to 593.5878006068257 Ohms
# ['signal1', 'signal2']
# ['Axial F [Hertz]', 'B_bkg [Tesla]', 'Gas density [m^-3]', 'LO frequency [Hertz]', 'Pitch angle [degrees]', 'Start E [eV]', 'Start F [Hertz]', 'Start F, downmixed [Hertz]', 'Time [seconds]', 'Time step [seconds]', 'Waveguide impedance [Ohms]', 'i_coil [Amps]', 'r_coil [metres]', 'r_wg [metres]', 'x_start [metres]', 'y_start [metres]', 'z_max [metres]', 'z_start [metres]']
# [2.71483866e+08 2.65083766e+08 2.69339213e+08 2.79283557e+08
#  2.86327509e+08 2.86840822e+08 3.28197444e+08]
# 594.4111368501582
# signal1 has a Waveguide impedance [Ohms] equal to 594.4111368501582 Ohms
# ['signal1', 'signal2']
# ['Axial F [Hertz]', 'B_bkg [Tesla]', 'Gas density [m^-3]', 'LO frequency [Hertz]', 'Pitch angle [degrees]', 'Start E [eV]', 'Start F [Hertz]', 'Start F, downmixed [Hertz]', 'Time [seconds]', 'Time step [seconds]', 'Waveguide impedance [Ohms]', 'i_coil [Amps]', 'r_coil [metres]', 'r_wg [metres]', 'x_start [metres]', 'y_start [metres]', 'z_max [metres]', 'z_start [metres]']
# [2.84085111e+08 2.87253504e+08 2.66957015e+08 2.86946212e+08
#  2.69609993e+08 2.77100165e+08 2.94278851e+08 2.91817147e+08
#  2.93913773e+08 2.93909752e+08 2.87464103e+08 2.92313442e+08
#  2.75728300e+08]
# 593.8231906971207
# signal1 has a Waveguide impedance [Ohms] equal to 593.8231906971207 Ohms
# ['signal1', 'signal2']
# ['Axial F [Hertz]', 'B_bkg [Tesla]', 'Gas density [m^-3]', 'LO frequency [Hertz]', 'Pitch angle [degrees]', 'Start E [eV]', 'Start F [Hertz]', 'Start F, downmixed [Hertz]', 'Time [seconds]', 'Time step [seconds]', 'Waveguide impedance [Ohms]', 'i_coil [Amps]', 'r_coil [metres]', 'r_wg [metres]', 'x_start [metres]', 'y_start [metres]', 'z_max [metres]', 'z_start [metres]']
# [2.99491420e+08 3.26856830e+08 3.41580542e+08 3.51374747e+08]
# 593.1083157345935
# signal1 has a Waveguide impedance [Ohms] equal to 593.1083157345935 Ohms
# ['signal1', 'signal2']
# ['Axial F [Hertz]', 'B_bkg [Tesla]', 'Gas density [m^-3]', 'LO frequency [Hertz]', 'Pitch angle [degrees]', 'Start E [eV]', 'Start F [Hertz]', 'Start F, downmixed [Hertz]', 'Time [seconds]', 'Time step [seconds]', 'Waveguide impedance [Ohms]', 'i_coil [Amps]', 'r_coil [metres]', 'r_wg [metres]', 'x_start [metres]', 'y_start [metres]', 'z_max [metres]', 'z_start [metres]']
# [3.13285541e+08 3.22583114e+08 3.24463041e+08 2.98508468e+08
#  3.49411050e+08 3.59892573e+08]
# 592.4719043025646
# signal1 has a Waveguide impedance [Ohms] equal to 592.4719043025646 Ohms

# %%
attributes_values[0][8]
# Out:
# array([0.        , 0.00013287, 0.00031825, 0.000407  , 0.00055281,
#        0.00071049, 0.00085313])

# %% [markdown]
# # Plotting
#
# Now that we have the data, we can plot it. We'll plot the data in a few different ways to get a better understanding of what we're looking at.
#
# First of all we can take a look at the plane of starting positions of the simulated events. This will give us an idea of the distribution of the events.

# %%
len(harmonic_sim_list)
# Out:
# 274

# %%
# Out:
# [[-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]
#  [-0.3520157 -2.1044441  0.       ]]

# %%
######################

fig = plt.figure(figsize=(12, 6))
grid = plt.GridSpec(3, 4, wspace=0.4, hspace=0.4)

# Large 3D plot on the left
ax3d = fig.add_subplot(grid[:, :3], projection='3d')

positions = np.empty((0, 3))



positions[:,0] = np.array(frame['Starting x position [metres]'].tolist()[0])*1000
positions[:,1] = np.array(frame['Starting y position [metres]'].tolist()[0])*1000
positions[:,2] = np.array(frame['Starting z position [metres]'].tolist()[0])*1000






ax3d.scatter(positions[:, 0], positions[:, 1], positions[:, 2], c='green', alpha=0.6, label = 'Initial Pos')
ax3d.set_title('Starting Positions in 3D Space')
ax3d.set_xlabel('X Position [mm]')
ax3d.set_ylabel('Y Position [mm]')
ax3d.set_zlabel('Z Position [mm]')
plt.tight_layout()

# Distance circles 
radii = np.linspace(1, 5, 5)
theta = np.linspace(0, 2 * np.pi, 100)  # Angles for the circle
phi = np.pi / 4  # Fixed angle for the 3D plane (can be adjusted)

colours = ['red', 'blue', 'purple', 'orange', 'pink']

for i, radius in enumerate(radii):
    # Parametric equation of a circle in 3D
    circle_x = radius * np.cos(theta)
    circle_y = radius * np.sin(theta)
    circle_z = 0
    
    circle_label = str(radius) + 'mm'

    ax3d.plot(circle_x, circle_y, circle_z, lw=4, ls='-', c=colours[i], label=circle_label)
    
ax3d.legend()

# Histograms on the right
axes = []
for i in range(3):
    ax_hist = fig.add_subplot(grid[i, 3])
    if i == 0:
        ax_hist.hist(positions[:, 0], bins=50, color='green', alpha=0.6)
        # ax_hist.set_title('X Position Distribution')
        ax_hist.set_xlabel('X Position [mm]')
        ax_hist.set_ylabel('Frequency')
    elif i == 1:
        ax_hist.hist(positions[:, 1], bins=50, color='green', alpha=0.6)
        # ax_hist.set_title('Y Position Distribution')
        ax_hist.set_xlabel('Y Position [mm]')
        ax_hist.set_ylabel('Frequency')
    else:
        pos_magnitudes = np.sqrt(positions[:, 0]**2 + positions[:, 1]**2)
        
        ax_hist.hist(pos_magnitudes, bins=50, color='green', alpha=0.6)
        # ax_hist.set_title('Z Position Distribution')
        ax_hist.set_xlabel('Radius [mm]')
        ax_hist.set_ylabel('Frequency')
        
        for j, radius in enumerate(radii):
            ax_hist.axvline(radius, lw=2, ls='--', label='Circle Radius', c=colours[j])
        
    ax_hist.set_ylabel('Frequency')

plt.savefig('initial_positions.png')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Starting position [metres]'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [35], line 8
#       6 # Large 3D plot on the left
#       7 ax3d = fig.add_subplot(grid[:, :3], projection='3d')
# ----> 8 positions = np.array(frame['Starting position [metres]'].tolist())*1000
#      10 ax3d.scatter(positions[:, 0], positions[:, 1], positions[:, 2], c='green', alpha=0.6, label = 'Initial Pos')
#      11 ax3d.set_title('Starting Positions in 3D Space')
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/frame.py:3804, in DataFrame.__getitem__(self, key)
#    3802 if self.columns.nlevels > 1:
#    3803     return self._getitem_multilevel(key)
# -> 3804 indexer = self.columns.get_loc(key)
#    3805 if is_integer(indexer):
#    3806     indexer = [indexer]
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'Starting position [metres]'

# %% [markdown]
# Let us now see the 2d plot of the starting positions of the simulated events along with the

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6))
plt.gca().set_aspect('equal', adjustable='box')
# Large 3D plot on the left
ax3d = axs[0]
positions = np.array(frame['Starting position [metres]'].tolist())*1000

ax3d.scatter(positions[:, 0], positions[:, 1], c='green', alpha=0.6, label = 'Starting Positions')
ax3d.set_title('Starting Positions in 3D Space')
ax3d.set_xlabel('X Position [mm]')
ax3d.set_ylabel('Y Position [mm]')

# Distance circles 
radii = np.linspace(1, 5, 5)
theta = np.linspace(0, 2 * np.pi, 100)  # Angles for the circle
phi = np.pi / 4  # Fixed angle for the 3D plane (can be adjusted)

colours = ['red', 'blue', 'purple', 'orange', 'pink']

for i, radius in enumerate(radii):
    # Parametric equation of a circle in 3D
    circle_x = radius * np.cos(theta)
    circle_y = radius * np.sin(theta)
    circle_z = 0
    
    circle_label = str(radius) + 'mm Circle'

    ax3d.plot(circle_x, circle_y, lw=4, ls='-', c=colours[i], label=circle_label)
    
ax3d.legend()
ax3d.grid()

# Histograms on the right

ax_hist = axs[1].twinx()

pos_magnitudes = np.sqrt(positions[:, 0]**2 + positions[:, 1]**2)
        
ax_hist.hist(pos_magnitudes, bins=100, color='green', alpha=0.6)
# ax_hist.hist(positions[:, 0], bins=100, color='yellow', alpha=0.6)
# ax_hist.hist(positions[:, 1], bins=100, color='cyan', alpha=0.6)        

ax_hist.set_xlabel('X Position [mm]')
ax_hist.set_ylabel('Frequency')


print(radii)

# Work out areas of concentric rings, not circles
areas = np.pi * radii**2
print(areas)

for i in range(len(areas)):
    areas[i] = areas[i] - np.sum(areas[:i])
    
print(areas)


# Calculate the number of points within each circle
n_points = []
for i, radius in enumerate(radii):
    n_points.append(np.sum(pos_magnitudes < radius))
    
print(n_points)

print(n_points / areas)
# Out:
# [1. 2. 3. 4. 5.]
# [ 3.14159265 12.56637061 28.27433388 50.26548246 78.53981634]
# [ 3.14159265  9.42477796 15.70796327 21.99114858 28.27433388]
# [43, 172, 398, 705, 705]
# [13.68732511 18.24976681 25.33746694 32.05835282 24.93427442]

# %%
plt.figure(figsize=(12, 6))

plt.hist(positions[:, 0], bins=100, color='green', alpha=0.6, label='X Position')

plt.show()

# %% [markdown]
# # Fluff

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# Pairplot for continuous variables
continuous_cols = [
     'Cyclotron frequency [Hertz]', 
    
 'Pitch angle [degrees]', 
 'Downmixed cyclotron frequency [Hertz]', 
    'Waveguide impedance [Ohms]'
]
sns.pairplot(frame[continuous_cols], plot_kws={'alpha': 0.7})
plt.tight_layout()
plt.show()

# %%
total = 5

# Quiver plot for starting positions and velocities
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Positions and velocities
velocities = np.array(frame['Starting velocity [metres/second]'].tolist())

# Quiver with custom arrow properties
quiver = ax.quiver(
    positions[:total, 0], positions[:total, 1], positions[:total, 2],  # Starting points
    velocities[:total, 0], velocities[:total, 1], velocities[:total, 2],  # Velocity vectors
    length=0.2,  # Adjust length scaling of arrows
    normalize=True,  # Normalize arrows to the same length
    arrow_length_ratio=0.1,  # Ratio of arrowhead to shaft
    color='blue',  # Custom colour for arrows
    linewidths=3  # Thickness of arrows
    
)

# Labels and title
ax.set_xlabel('X Position [m]')
ax.set_ylabel('Y Position [m]')
ax.set_zlabel('Z Position [m]')
plt.title('Starting Positions and Velocities')
plt.show()


# # Boxplot for categorical comparisons
# plt.figure(figsize=(10, 6))
# sns.boxplot(data=frame, x='signal', y='Energy [eV]', hue='trap')
# plt.title('Energy Distribution by Signal and Trap Type')
# plt.ylabel('Energy [eV]')
# plt.xlabel('Signal')
# plt.legend(title='Trap Type')
# plt.show()

# %%
import numpy as np
import plotly.graph_objects as go

# Extract positions and velocities from your dataset
positions = np.array(frame['Starting position [metres]'].tolist())
velocities = np.array(frame['Starting velocity [metres/second]'].tolist())

normalised_velocities = velocities / np.linalg.norm(velocities, axis=1)[:, None]

tiny_velocities = normalised_velocities * 0.001


# Compute arrow endpoints
ends = positions + tiny_velocities

# Normalise ends

total_no = 30

fig = go.Figure()

# Add starting positions as scatter points
fig.add_trace(go.Scatter3d(
    x=positions[:total_no, 0],
    y=positions[:total_no, 1],
    z=positions[:total_no, 2],
    mode='markers',
    marker=dict(size=5, color='red', symbol='circle'),
    name='Starting Positions'
))

# Add arrows with arrowheads
for i in range(total_no):
    # Arrow shaft
    fig.add_trace(go.Scatter3d(
        x=[positions[i, 0], ends[i, 0]],
        y=[positions[i, 1], ends[i, 1]],
        z=[positions[i, 2], ends[i, 2]],
        mode='lines',
        line=dict(color='blue', width=6),
        showlegend=False
    ))

    # # Arrowhead (a small scatter point at the endpoint for visualisation)
    # fig.add_trace(go.Scatter3d(
    #     x=[ends[i, 0]],
    #     y=[ends[i, 1]],
    #     z=[ends[i, 2]],
    #     mode='markers',
    #     marker=dict(size=4, color='blue', symbol='triangle-up'),
    #     name='Arrowhead' if i == 0 else '',  # Only show "Arrowhead" once in the legend
    #     showlegend=(i == 0)  # Only show the legend for the first arrowhead
    # ))

# Set axis labels and layout
fig.update_layout(
    scene=dict(
        xaxis_title='X Position [m]',
        yaxis_title='Y Position [m]',
        zaxis_title='Z Position [m]'
    ),
    title='Interactive 3D Quiver Plot with Arrowheads',
    showlegend=True
)

# Display the plot
fig.show()

# %%
harmonic_sim_list
# Out:
# ['../../../../Desktop/v2/Harmonic/89.5deg/out_087f4090-6cee-4257-9be1-0de405dd2039.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_6f5f153d-9547-45d0-85e1-43d3d000b8da.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_799f6692-0430-41a6-a871-95d8f41fec27.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_5aefc6d4-937f-421b-85e6-7fc6ab6779b9.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_38e7d13f-ef18-4a3e-96df-41d21828feee.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_815e33d9-de04-4770-b47d-cd38878b44e0.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_4bdd96ee-d07c-4724-9f10-98a4126cc86b.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_4cb21535-b836-4095-8199-f9c6da7ad33e.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_87c3c1c3-8ec2-4c03-aa06-bca03125a1aa.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_8ff2c9ff-7114-4973-b927-1932b283bfae.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_ca1fdd91-bafb-4a8c-b157-fa6fde377f4e.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_aa757e34-0546-4212-ba7e-7a0be7d619bb.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_d58b7bfc-4ccd-4afa-95ba-1548ab581f8d.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_1f5e10bd-1c35-49e3-8416-65549c4942f0.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_779d5f71-8926-462a-94cb-e7dba006f9dc.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_a61728f0-cf65-4100-850d-7e8522cdef6a.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_c2a11d7a-840d-4a58-9a78-e5f419ba3351.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_1f5c7bc8-a143-4b8c-936f-12cbd41b74a4.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_c2d75b81-d66e-446f-b548-5b380f1216f9.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_fdb03faf-7599-46bb-b528-74d81d7e880c.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_00269b02-140d-42cc-a805-35d884223650.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_e17d64ed-3377-4658-a932-afc27ae7f33d.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_c4c96fe0-b8c6-4a0c-89c4-09ed10591c3b.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_11cd0931-98e9-4a48-85d6-4d79e8e08482.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_65ec80bf-256e-4e51-bbfd-4ee28b339504.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_ca84fbcf-e196-4ae2-b6fc-d0b3dfafbee7.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_e5527138-221a-4d69-833d-07dab0571913.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_a2f57005-9c02-4890-b145-279f91a018f2.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_4274deef-164f-485f-8b5f-0483253e8545.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_ad2f85db-d56e-4d33-bea7-fcf46f1f16aa.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_232c785c-523f-46eb-80a3-41efbf7a7756.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_2018229a-c2cc-43cf-b4a8-7c8135da0369.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_ed7c21d8-4a7b-4bfc-9cc8-13aae529444c.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_65226a73-0264-40ae-8f27-e0f5adf8f5f0.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_dafa2ef2-9159-4136-833a-dcaf92e8db2d.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_ca2e572b-5057-4fe9-965c-0f015ac8852a.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_0c5209af-8086-4b35-982a-d6ab126693f5.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_26551c4e-a715-4869-9e96-3bc4fbbd1b0c.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_7ff3ed56-b629-4c68-b392-d61cf68b7510.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_bfc0789b-2b1d-4572-84df-ac41df96cacd.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_128736ba-3543-4403-bb9c-3b105a0dc544.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_c57338a1-714f-4d4e-a7f3-32d80d8dec84.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_465b7140-3989-48b7-97c9-94c58bcb56f2.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_17c26513-3360-485d-a7d2-115d839ed4cc.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_a9e741a8-3ddb-4c5a-9b13-65687c4f851b.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_f5857a12-ef29-4d61-9e7d-25787ecddd7f.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_800e99a6-b702-4657-a923-59a28d76980a.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_25bfcc12-9dc8-49dc-b751-3332b96f49c1.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_d7683143-2803-4fe1-ba19-dc36e6083713.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_0e7db1b6-991c-4bd4-b5f1-edb724f2dcac.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_37b6a2eb-ed76-4d21-a19c-d535d1b5f2d8.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_38a9189b-578c-462a-838b-9ac1104390e6.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_5508e90c-80da-4390-9dcf-0a1f2d31e8ed.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_099dfd5d-60ea-464e-aef0-4d7f9e9f0715.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_deeae480-89ee-491d-b595-6528c1a6cea6.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_641d29e3-8ef4-4fac-8a5e-cea2e5d8b0bc.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_9c4219f3-8672-495a-90b2-ad9af8c8990b.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_97619370-50bf-4845-a53c-5be4fdcb7703.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_020783c7-f863-4f4c-9b12-80f65fb8d5ea.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_23b235ba-dd89-4370-a958-f29abdbc94f8.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_b3393177-77c8-4377-b18e-abe6d82298ba.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_752a0d79-bd39-4b71-a39d-835ed729ff96.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_f7b4c1a9-4a04-4c55-8a7e-143c1e4eb831.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_dd13947d-089e-4200-ba1a-0775c2c2ccc8.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_6efadda1-21ff-4fd7-8be4-2e0e3bfde2c2.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_6cfb8782-a7cb-4bbd-8ad5-305f1dde3653.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_6b8fcdbf-9248-4961-9799-ded53967b3c9.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_1f7e8e1c-5297-41e7-823a-1d865f3815c5.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_e4c5fbbf-d0d4-42a2-8b22-b24f93af0176.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_b7d64eb6-16bc-47bd-a66b-47e10a6298b4.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_2bf47525-438f-44f3-8e18-3e23cddaa191.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_700c408a-9887-4154-afff-aa2331a929d5.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_41b6dab8-23c9-42ac-9a84-d479d97cf5a9.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_4f9630dc-e00d-4502-87fd-c12965c5b87c.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_9fa9bd6d-7c2e-4bba-a4d1-680517742498.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_4b6180e0-f8d5-4f0d-9041-65912335f420.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_51db499d-c8ea-4cce-884b-d9c3e3f44ed1.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_dd6fc7aa-dfe0-48a4-9abe-8bf2d6d73a26.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_663a1c58-f6ad-488d-a656-02eed5acd4ca.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_73b18503-fd9e-4ce5-8f56-349e7cc0a456.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_f02d6009-afe3-4af4-8d70-bd75c4210b05.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_a76b2904-d764-49e7-9df5-7756b19b5d97.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_af67fd61-e71f-481f-9f5d-f70ac6ded9a6.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_b1aa4d9c-5b90-4af9-bd5e-27f9f6accbe9.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_f3029590-2d96-4ae8-aaf9-59cd438c3c17.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_eaa375c6-d861-48eb-b595-415b7641af72.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_d0d17abf-da97-4007-8bd3-6c010063e676.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_e2207a70-12da-4dac-9060-e111b2aae13c.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_3019fd64-a802-47bd-aed0-ba8ea888aacd.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_08d36c3a-c37c-4f0f-b203-89af51f9c8f9.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_b2063233-e257-402e-be07-7c4508124a92.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_e0093c10-8c82-425e-800a-ec40659ce24e.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_302d2377-7e75-434c-9437-d39a0c060574.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_da87d104-a613-4f15-a743-e7ef13af14b7.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_31d941a1-9700-4b4e-b4c5-1ac79a8538d7.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_804f565f-1601-4033-973d-fd67b0f85608.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_f787d4e1-6942-438c-94f3-dab10dce700c.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_36bd839f-9e5d-4c26-8eb3-7d0cfcb5a2ec.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_35348844-d645-477c-aae7-372e2e83457b.h5',
#  '../../../../Desktop/v2/Harmonic/89.5deg/out_79ebafc8-8c7d-4486-b8cd-5296fa1b03fd.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_b6904a31-7e4e-4282-8ac5-0715b65af626.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_cebcab3e-1612-47f6-af3b-15da49f5e73f.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_5da408a5-8298-43ac-8285-e8fae2272888.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_c6d3ddf9-aa42-491c-994b-9787010a4665.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_5c7aedf7-ef5c-4204-b7a0-8ff4131753e8.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_c44f15c4-e4d5-4abe-8af7-e53a5ee0feec.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_699e2e61-afe5-4c83-ba57-bf2ef4ad1a2f.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_6e0ea340-51dd-4202-b3d6-350344f58e59.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_f94b29e9-79e7-4661-987e-05e9de4ec2b7.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_4b66a85b-ed75-461d-b046-76ab91802ae5.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_afd47fbf-f85d-4316-a6e8-5a01edad8b50.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_b46500d4-658c-4fab-bdc8-95ccfdc08780.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_37d44d46-b78f-4b28-a531-a984971ed12d.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_0ad74f8f-ec02-44f5-a5af-5c69bef4774e.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_9da210df-7071-4316-97da-d3338d45f03e.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_924f5c69-52ae-4dec-aba7-28374bf00572.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_444caa8e-e53c-4289-ad9a-5874d2f98995.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_d7e3d240-3808-4c74-ac20-ab0face689b9.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_d386de71-680a-46c9-9b4c-c6b09ab4692c.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_7c553927-d395-4e7a-94a5-b9edeaac04fa.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_428e9f2a-9159-44d7-8a6d-d17e7ec568b3.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_97102d0b-701a-434b-97a0-1dbc8f6e52c2.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_7878ca7b-1c58-4ca8-b327-052aa11f42df.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_602d7567-1134-40c0-b68e-cbab347e40c9.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_8727c5e4-7ed6-40ea-a77d-3d4c4c33d093.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_46eee6fc-f647-4e15-baf5-afeca28e7f82.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_72cb8750-cabd-4b31-95a2-60507f0b72a1.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_bc246802-4d02-4136-b257-38037d404b66.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_4b448c48-6556-43de-a482-e203b8313b98.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_c2388233-88a4-4b66-a74c-6c824d849990.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_f7503791-b4df-4446-b84f-da53525c618c.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_01597900-03a1-4792-9433-02f28d036ccf.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_0f800375-3d75-4290-8aaa-22c5bab3c811.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_5e84d2f0-9026-4503-84d3-31bc0d9ad55e.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_4b7d3d4a-0d5f-43e6-a33a-47692e485f63.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_ee706066-eb9e-4cae-8116-54097494a362.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_84119077-db42-43b6-8a24-8f7a1cd5489c.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_8f7eed9e-294d-4e92-93ed-a818a1c2c9a0.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_ea765542-415e-480f-ac6c-8bf57ea5ad36.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_9fb3e7cc-58a8-41c0-bf04-dcda403cd74f.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_15dae44e-9364-401d-9f3d-5d8d544b84b9.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_1c3f8673-3300-4b82-b5da-e2936eec9c84.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_90a3527e-0987-4947-b5b4-51e28846253b.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_ca13ff95-4191-43e8-a125-68d226ddd5b8.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_08163e2b-61e3-4fb6-8e82-4b9f380b8db6.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_b5c39e15-eb89-4b2f-905a-135e34ad4b81.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_865e0410-ec54-4e04-8a64-abda1513b1fb.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_6eb9eddc-11f9-4d28-854b-09b1b7a4384e.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_621fa128-4a81-4240-b1a3-e0ff55c7fb5a.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_7ea60da1-28bc-41f6-8c8c-5205695531b6.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_2e465a62-965d-42df-b0a5-af18c1dff13a.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_2fae73d5-1b37-46f6-8be6-a1fdd9c12017.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_56c2dc14-8a10-4d9f-b224-064b84f15a0b.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_a400f78d-78c6-4ff7-95fd-69b4ebb43368.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_c70b1fa2-9b48-4633-a605-5ce7d45d2ecd.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_c2c11c54-4966-4c92-b9ff-1deda58c3cb1.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_f04b38db-e5c7-4fb4-b115-6e5bb55309af.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_5af06f0c-72a9-4c71-9665-eb7a8ac5a69d.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_f1f7f743-d308-42af-a319-c5f55f8ec72e.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_6074df28-542f-4b95-b025-1daad0a308a2.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_b01e2246-df24-4729-92c1-b6641e531340.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_5b1a4bdd-f584-436e-bdcb-73493bad41c1.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_f275ed16-91ef-417d-9fbf-e256784b382a.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_2ca3806a-d4cb-465f-8deb-bacc2940e2ac.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_ca3021af-9cba-4598-8faa-0bf31af6e443.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_ba493d40-5edf-49b7-8fe6-3680475f8b6e.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_77321d93-6f74-4669-bfad-192a77c949af.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_1e30cfde-da25-4e34-a2a7-3e80ecc83a69.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_34955f1a-544d-4fb0-8804-e5e503a92554.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_16b1e98a-ae5c-41c6-b7f4-01129a7dd592.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_b233738f-eca8-4271-a42a-437457d94bb8.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_b41c9f26-822c-46b2-9500-0746db40cb09.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_56671f1e-9209-4f51-ad84-79fddb93cf23.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_7bc6c641-e580-4853-9e85-31e6887a7358.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_db42a1eb-14d5-448f-aedd-b48346752ba1.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_f2db2191-924a-4c89-8216-e5ac1bd3e4ef.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_25c1f52f-efdc-4deb-9af6-d1cd5eab8728.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_f9e39cd1-8cc6-488e-90ca-6f06d4fe7a9b.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_86bdd97c-d9ff-4a58-8454-4165e533b389.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_2ac5e346-767e-411c-ac9c-75982acfd78e.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_2d2f45c8-6a30-46ef-94a5-c255cd89088a.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_66a22cfa-2319-4bd9-ba4d-ff41952bb8bc.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_c0964fab-6d23-40da-ba1a-33583f9dc47c.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_974cd6d3-1873-4d76-a2e4-35390f4df1aa.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_6f44634d-7226-4a8d-9a32-d27d5fb8054c.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_c7639819-fa67-4a03-bf3b-453a5bf4e40c.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_d203ae4e-ff00-491a-a40a-3ad25caf7c06.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_90887595-72a6-420d-ab6b-11fbcb862f92.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_9d69a112-af74-4ddb-8653-bd97eb7b0f33.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_174cdba1-abd6-4f87-a423-ed2d5d075b1c.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_ffaf90ed-0425-431d-9462-ef2577f519b9.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_bd0e50de-f07b-4753-901c-3f62de5045d4.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_5b81669e-5084-4872-ab06-390b4bc8a26a.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_66a7755c-b034-4071-b059-89ea95133b84.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_9bc81d4a-eef5-4d3a-96fe-b0c77c7c72a9.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_96c069f2-876f-4b8c-83d3-4e41a7af4f55.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_0052be87-64be-4b8b-8164-c7f64cda23f6.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_5fcbcf28-466e-4d74-b4a5-834680804573.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_bb1dff8d-a1d0-41e2-af42-a1ffce837b87.h5',
#  '../../../../Desktop/v2/Harmonic/88.0deg/out_21eb8a6d-96a8-47fa-a6d3-5ff472665e43.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_1a0ad631-1153-47ef-8cba-ea9ab0cefa3d.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_73e9b332-d833-439b-ad87-1fb475544d2e.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_d1374ffa-529b-46d0-887d-e5ba5ed332ee.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_5c5d7f8c-4b6f-4844-bf7d-f4014fcf9e57.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_59ead0e4-82ac-447f-b43f-46f00850ce6b.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_2dc3ccbd-6fac-4605-a157-c28841bff14e.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_52880bdf-d9e0-479c-a634-077eec5ce15d.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_a7fe9317-ca19-44d1-a736-a417230b10c0.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_20ad61df-89e7-4139-8f78-2df08e9fa58e.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_90913df0-def7-4648-be0e-a5d44f2953b5.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_9467ae3d-1896-42ff-8434-5d30a578f8ae.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_3d3f63a9-2ba8-4215-8aef-eaa8ecca486f.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_edf2051e-cb0f-4e68-9dbe-de30811d1671.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_c256c345-4eac-4eb3-a0a9-747f2d12f592.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_c499fd74-ca9f-4ef1-b5f9-e6623741dada.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_b8d2c734-a22b-47b6-8149-5d2b657309c6.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_26442a66-b32a-47a7-8909-0146b1edc2a7.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_5c31e455-8bc3-4faa-9c8e-b26aaafb6089.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_26ce8502-5262-44d6-886c-b554a7ef5ba4.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_a13f9dee-b59d-4a6f-a6d2-5ffed84b663a.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_4ce2aa52-0a61-45df-b50a-bb799fb4df67.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_f810249e-0d34-459a-b848-78f64bdec9e6.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_61aa3ae7-bde0-4f15-9f8d-30ebd5451fcd.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_7175447f-2144-4edb-87bb-9f41b470373f.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_d552210a-b3c3-4b0a-879a-65f3a9d619a3.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_5b067719-d6cd-4c88-aeec-df8752cf7ebf.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_c810b272-0bde-4bd4-adcc-dd3a3f1ff1ad.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_5604a730-6580-4143-a2ba-2dea4ffca5e8.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_0433c6b9-991a-46a6-9190-250ad10da6ce.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_2dbfea1d-f99c-4e43-be90-f4def35c19e7.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_80f7b64b-9af1-494e-9540-fbeca17a8eec.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_e6f6efa2-7dca-4330-bd10-c0eb8f9ba41b.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_50101bda-f320-410b-9def-22064ca7f31a.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_540ee81c-a687-4b42-b2f8-d3e4bc684e7f.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_479716c2-fc0d-469f-a33d-0cda4a12e3d3.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_7ca1879d-90ff-4428-bf09-f74940b7a653.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_1223bc54-cbd2-414a-91c9-6498cdeb63e3.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_eaae4f04-2e93-42c2-a35b-8baea80604de.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_55196fd5-175b-4957-9775-0afbb8f09d38.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_00851a3b-18d8-4967-9cfe-dc79f9964265.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_e4f65db2-2c8a-4f79-ad74-fb6c0d0270d3.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_4f40df65-4957-4963-bf73-91bff0ba7128.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_5a16d622-0a46-4159-b945-88dc70b50a94.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_a3c3136e-3d51-4282-a982-469bf0cd300f.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_88d2d974-ffb5-492d-9959-1eb6e85e9117.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_40743d6c-d5fd-41b2-8ad4-e53b5cd0e4da.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_5fd1d1d4-8095-4c8c-ba1a-c826e19b27cf.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_cad62278-b9ab-461f-93f0-008890e948ea.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_b1a8ca06-167d-4775-b587-51c83f6923c0.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_4ed79216-4317-49a6-aa89-4f07e13a8f88.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_0fa281cf-4941-4498-9497-391679cd663b.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_a5ca5f05-7c9f-4af7-8231-f8fdf55eb7c9.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_6a03bb8d-fb4d-4e04-8fbe-6264f09ce3ac.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_df9df29d-bc42-4646-b085-206be76e1e30.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_be498674-ecd8-480a-b18c-f468156f54e5.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_8d5f590f-2f1d-4a07-b9e0-d11c5f12860a.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_7fd23ab9-b181-47cd-ab99-d22854d28e4a.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_87d5be22-e468-49ee-903e-c70ffaea3c98.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_bde52e9a-0c6b-48cd-b45d-1d982de86b2d.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_d0a5db72-b820-4f55-b107-e4abf6a67d74.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_b862505b-0118-4987-a6cf-987e87ab60ad.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_7ca1b213-b0bc-4717-86f3-749b9a950da9.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_8d0d26cf-6d79-41c3-8639-8ac5340d3b91.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_9d19f6e4-3fd2-4fcf-be83-f2ccfc8bb6b0.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_aeec2800-2ccb-4ee9-8362-458ee7abd209.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_acbb3f11-9162-4aed-af34-a0e2f399c050.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_aee7b20f-1d89-4bdc-b268-47117e5c905f.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_5542ca49-c4c8-4f5d-9e06-dd611b1ad125.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_76760f8b-7c67-4c37-b896-80c751e2d762.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_05e47b24-031f-449e-bd90-dd0cdb7e0f24.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_32cf6b52-ce32-46d7-88ad-b6dcc120b3d1.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_679046ff-12c7-4cc1-b6cc-bf1960154742.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_8e92a3a6-0cb0-41d7-a1a0-2a4713d36c2d.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_b9bf7eaf-f1df-47d6-af5b-4df805fa8557.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_4f94f957-6b67-4390-9374-b101091bd7c3.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_c6b05476-2535-4cab-bd25-3e558ab7e407.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_023c3f20-0af7-4c47-b97a-7122103b89ba.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_68b8786c-9ff5-439d-bbc5-22ff0d8db51e.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_1ad916db-154c-46fe-95cd-f6c1c5de2ebe.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_89b7ef17-1399-41b2-8d2d-cf903b5de39e.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_1377ede5-8dd0-4f52-84e5-dc4742121ceb.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_cb07eca6-b163-4519-a3ea-22926821b6d9.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_e5bddfec-3191-4327-a9e6-3334c0b9ab77.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_5eac4d14-f2eb-49bc-bc58-f0674cd66b67.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_b02fa2b9-3214-44d9-a606-11527afafe55.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_b2001813-59a5-4962-a55a-c68a4ebf8506.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_4543a29e-0381-4683-bf08-a470c6969285.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_a9fe8226-a6a0-4d2b-a65c-2e39443136f6.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_2bc70f39-f25e-405d-9f2b-7614f45d8949.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_5b30781c-6090-47f3-8e33-1ab8ff01d1d3.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_2cb0f1cf-2e4e-47bc-b089-15b21b857dd1.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_269ffa37-4e53-4201-aa78-3979783fa116.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_b4e1da64-0a31-4952-a313-ca522798030f.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_bea75e03-5d65-4b94-8602-6e78b04a7d75.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_6a6cb4ce-ccdb-4478-83c3-d231a93ff8cf.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_bc0ea574-74a0-4d62-8c7f-8c2866b27be1.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_7d95dae8-d9ee-485f-832e-afb28c15db75.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_3876e50d-108e-42df-875a-a3c8ad593416.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_c46ca8fd-813a-47e6-9888-a9bba0872ab9.h5',
#  '../../../../Desktop/v2/Harmonic/89.0deg/out_81ece44d-fbc0-473d-a51d-fa5fff21a194.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_ea92188a-283d-4401-b190-2d7e655c6926.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_34a8a993-a117-416c-b814-3d92632a563f.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_ba600d97-2cd5-4842-bd99-a5fcf479da24.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_13f908e6-4c81-4ef4-85f9-fc2661381a3d.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_54cfa977-e83f-410c-b828-c771658260c6.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_052861c0-2fea-49e6-bb07-9819ca0a9630.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_00aaf946-8c77-4066-b7e7-4076eb2abb07.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_17cc923e-9705-46f2-8d2f-f9a519a3dce2.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_27c1c822-0c5c-4862-b263-10ecab44e4ab.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_3f193d82-9e6d-43e9-a5fd-059c67b22688.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_b052d46d-4757-40c9-b0d2-a2cad6d1164b.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_528d9b32-fee4-4a3e-a46c-6cb55238d3e7.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_846aa79a-a2b1-430a-9be6-ffa2ce252706.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_5fc43598-5f1d-4ac1-9c0c-78e04dcbde50.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_6e95e790-d842-4f73-b915-93f9b1a6f273.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_5d8a4aba-1afe-4cea-b28b-bab07d918bde.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_2c1a7bc9-3ba4-4897-8c32-2ac383338080.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_5f8b482b-6e3f-4806-8198-542248feb32c.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_f45b8201-4c52-48c0-8a86-5b0b4fe2e8cf.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_7d65fb5a-d7ed-4a75-8ebb-711bddb8d43c.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_635771c6-e951-4797-aa5a-ab23b4c2b901.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_1613528a-ae50-4cc6-a0c0-8bb8ea3acc68.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_d52a8427-c97a-483f-98fb-528477ef8c35.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_576a2141-f867-4944-beba-50452848aca5.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_e9be0707-4429-449a-8000-4f3af41d17d9.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_b919fd6a-6b16-4295-8abc-2f8d1e3d8c44.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_54f19a01-5117-49ff-b4bd-7ae7f75f7501.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_2659bd76-8be3-4c3f-b878-b1dfeaec1b3e.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_e25b30bc-5291-4863-a371-465aecf310dd.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_0557d7de-e986-4844-bd86-8c087bfa9646.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_eb8d45a8-f2b5-4bae-b6a1-9115e9a9d96c.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_4fb5ea0d-58b8-4986-ba43-140882c734c8.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_6fb00256-b003-416c-ac18-438770b2f537.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_cf614cf1-b344-4409-98ca-2f9f3d945515.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_14116ade-baff-4a1f-92e9-3905bb631a6a.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_37eda008-bdae-4df1-8e20-32a6ee47088d.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_a35ff10a-64a3-43a3-8a7c-6f9301679acd.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_6fcf57ec-9a63-4ed4-9a2a-53a4ac2c6e3a.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_43bb7d8a-f39f-43b0-af22-257a50e35bda.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_7ecb6db9-736e-4248-b251-8c15add4909f.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_d1126595-3732-471f-9b5b-c08bc5c56d36.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_029cd038-662f-419e-97b2-4c4d7f04838a.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_bab3262a-75dd-4bcb-a0bc-abbe4f9d8db3.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_ed03ea4f-d29a-4056-91cc-4f03fb09aab8.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_0eca13fc-ec03-49ac-b48a-3b950225c478.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_d4a998f1-bc8c-48aa-8df0-9914ad857c2f.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_8f5c1950-ac2d-4ed4-9b74-7981c2f08627.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_ab4436b5-b2c8-49bf-b03e-d338407e2dc5.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_3b35a397-638d-46e7-ab93-1647a8b828ba.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_efc23101-4544-4f42-9afb-c49f4fdfddd2.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_abf815d5-dec3-46af-a4b1-2eea750cae2e.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_25ef3dcf-8f27-43d9-af4d-c54c5a1b1055.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_d47a8c9d-5755-4e43-93c8-9192735c9296.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_3faae137-d4e6-4cfa-a177-e1f5d64d3bb8.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_25eef1f0-dd36-4e7e-b935-633f7e309e07.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_4b59fea9-1a9b-4b48-a7ae-b41b80f404f3.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_0fb6a2bc-1808-4a34-919d-cd76cbc3ce24.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_da2e3b95-ae35-4d35-ae05-a465a7e7b3bc.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_1744bcc7-f427-4a7b-96fc-1f4a9e159670.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_21ae0470-1e76-41a0-be7d-01bc753e7463.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_013bc3e5-c82e-4c82-a36c-9c038368135a.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_55103668-f9f3-43c7-bd44-1d3a2d3a7493.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_7fefee93-08c2-4be2-bb9e-82a87befe71a.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_ef19be65-ce05-4c39-9b16-d15f916cb32a.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_10aeda3f-4b3c-4276-81a7-c6f46a39de9c.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_bd73f65c-e045-4680-a1f2-54662956e267.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_345928fd-882a-4978-bcd3-10b4df2770b9.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_a269b294-8512-42a9-b73f-d6f8262ff9cb.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_54ab68ba-7974-49c4-b07c-78ad4895cfe3.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_b10bdae2-475b-4e6e-a10c-7274fed74e94.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_45e0a249-e382-45c6-bf2b-02f64c83a41c.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_d8b01250-dabc-478d-8d55-07810ad87583.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_59a88bb4-e0d8-4ee3-937b-7dff940a4d30.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_d4a209d0-885d-49de-85a7-54daae310d5b.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_6999562f-4cc8-4ac5-b977-dec34f63c98c.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_53f0dfcf-ef84-476a-ba60-85935c6f38e9.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_0a1bc7f8-6e25-47f3-9743-f404227c3d0b.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_e44fe483-ab5a-4758-abec-21ff1f56ec63.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_1cdb59d7-db03-46c5-a3e3-fa357d1e04ce.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_0be833da-94a7-4e3f-9106-7874c327badb.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_bb936c1a-7baa-42cc-8a24-c6b4dc382c14.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_29c341cb-04ec-4f4b-9d3f-d2e7b7f617df.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_d2321df9-e910-4b82-b598-f11375662355.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_709ade6e-306b-487c-8936-f2300bd06a45.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_c674ddfd-06a7-43e9-8ae4-ff771f441d85.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_41821cac-3c22-40ee-8905-8c3923a02896.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_a3ec8d4c-7e08-49e9-8531-4684d97cf3eb.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_c77038a4-cc00-490a-8f3e-12e44f6da960.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_5f71a9ee-dc90-4956-b288-5a159c4a8c7e.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_3267afab-0789-47ce-9cb0-c151d30c8a1b.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_99d0a12d-7f85-45ae-9064-76521b850efe.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_3044b5c6-05a0-4192-b0c3-aaff0988bc36.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_614a2387-f4f9-457b-8a32-101534943fce.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_c250a4c0-41ef-4fcc-b72d-6ea1506247d2.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_b46617fa-25df-442e-9c77-6373e549d79e.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_f7afc989-73c6-4379-888a-82ad26147f86.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_6ee11c13-1ca4-4d69-9f78-70f27370bcc4.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_c12e7048-dbcf-41a7-a9b0-f6e65b9aac52.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_696c6af0-8b1f-4b61-a401-63eebc479461.h5',
#  '../../../../Desktop/v2/Harmonic/88.5deg/out_7d15a5a3-1b6f-4dfa-bcb1-3e7d5d4461a6.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_4976c7bd-743b-49a2-99e4-3f13129d44f6.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_7e6aa318-da4b-44df-9c7a-1d3aa145ec95.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_0f1b9486-39d3-4506-9d25-26124797daaa.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_2b704f91-eef3-40eb-b3f7-66018ec408f5.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_97f6e7b8-4717-4e22-ad4c-4a36756fd2c2.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_7aa3c359-e65f-4d3b-ac30-8939462c00a9.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_31cae1d9-c62c-403d-93f0-2e2a81c79948.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_fccfefa1-82b4-4bf2-9e75-0a792badcf32.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_9da4ab31-7923-4dd5-ac10-43fc72270166.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_c61fe326-c0c5-40fb-bf91-788e3e80c458.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_2e1fad5f-7d9b-4757-a091-7d663bb39524.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_64f1d04b-5c61-43d0-a607-f72ccb2e73a2.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_c16e4ef7-898d-4009-9c90-4a1e1a5fc9ae.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_4367ae67-ba83-4078-8355-7723e6e4821f.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_b469c180-2cd1-4b37-a54a-be83169943ae.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_c480765c-e305-41ea-aed6-d538b7e690aa.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_3e5ebbd2-24dd-4f9c-90a9-3ba3c702d90d.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_824ed15d-adc1-4f40-8943-d1311f5ba7c6.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_87cd4a49-7c12-445b-b011-7187c11b9ee2.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_bce80511-e97f-4d3d-bf99-f8b6ea167bd4.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_c766371f-ad7d-4a62-addd-be6e40c2a243.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_e972e1bc-9ac3-4eed-b55f-1c35fee82ac9.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_910fe731-5fc4-4e94-9bc2-c393f923c3f0.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_e15ae87e-e64f-418b-9020-87f4736859d5.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_253c37b8-5eec-4b31-8941-f9dfe65b66b9.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_ba989b18-bffb-4d10-8d35-1926056f591c.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_a3140f60-9be3-498c-94a2-b764dbde8319.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_00f44594-6adf-4caf-84de-6332610be600.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_efc50672-ca98-4b66-aa88-45e739fe79c6.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_36273bb0-9fc4-4da4-b55a-fc1f10d0a337.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_44635470-41c6-447d-9942-5acd31adc379.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_59a76ef7-c006-4183-8eac-ab566f96a2f1.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_c6e4a978-e271-40e2-81bd-f536f89e9a9c.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_95df0dbf-a699-412f-9454-f8fc485b9024.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_19977e8d-ae73-4700-a03f-0de6bd2cc89f.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_e12f6407-8832-48c6-88f3-65c1ae8bfb12.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_b05965cb-7182-4e9b-83b0-bfa331054eba.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_769d36b2-799d-4fc7-81a6-1be603f249f8.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_01a8030e-acff-4668-8b46-67867bd1814f.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_248b3cd5-f36e-4a61-8ae2-c992f39edb8a.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_03e7dbcb-ce57-4203-b077-5494bc465bae.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_2b20d0da-78d1-40c1-9e33-7dbe5790a786.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_1e6fcd43-01fc-44fe-92a8-979e1e9270e8.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_dd97cee0-89dc-4ca3-a1e5-63718c3d90e1.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_8e178af9-fd43-459e-971a-947633956ae8.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_d031acb9-2947-4b03-9f5b-30f70d48c272.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_52606c3f-200b-4323-936d-67a4caa0e46a.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_066f6056-9088-4d62-b400-0e7fe41c2347.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_343dc873-bc13-4375-8d88-f2129cde0fd6.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_1b281597-d5b7-437b-a962-d83840dbd1c3.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_ef4b5ef2-ff7b-436c-9b85-6bfbd1625cb9.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_908b0f71-7f23-473d-bbe1-b902d186cfab.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_1024c43d-0726-40c6-8b59-2e104179f890.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_65bf1bb3-c20e-4154-b1be-eb4ff047ef2a.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_20672790-50e0-4caf-9b8a-4d7a8ecec689.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_a1992805-291e-47af-aee9-bf78bf4e82f4.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_2e1cf92a-28b9-42a7-8a6d-908877350029.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_2ec4d533-d57b-47f6-aae1-4b9a71b70add.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_7c83e67d-f2d8-46a9-8750-bd8106d5f793.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_038a1490-acb4-491b-b7b0-0b34a11efae5.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_0b304bfe-52e5-433a-aca6-eecceb062e3d.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_7aaaf9b9-6359-483a-a667-cff400d8818a.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_a25d5b5c-27ca-4f0b-b87b-a6df3d60e921.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_db4d4df5-8ad7-4b56-b582-d4205c815d9f.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_817d3695-b121-4d9a-9298-7dbb3aa08f00.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_623bc6eb-a17c-436c-8788-cddbf2b51f15.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_0a5a3368-a72b-4392-9ccd-bbcaf9762cbd.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_7d859207-6c74-4136-97c1-bb24ce27314e.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_b572bae6-be18-4b0d-b435-53fa5a18a504.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_ed4c05ba-53aa-4a5f-8acc-0509cd4b5c33.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_3a22b1be-71ac-4be2-982f-fc7284e63af7.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_62bea76b-f0e7-4665-aece-3a526b75af86.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_6af1ca6d-429d-4d40-a516-a6576447a9f3.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_db8ba722-e7fc-4c01-a946-6614dc7c7f3a.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_81bd2326-0f4c-4b5e-a5a3-0a726dda9164.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_38e6c2b1-f9c7-42b7-aa41-6356f0dc584b.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_bf3e06a8-fc30-480c-ade8-514613d91a7b.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_08070d92-7fea-406e-9113-f426d7b090f9.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_54efc53b-5e2b-4e15-97b9-1d37f7ba3b2f.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_aaa77266-bb87-4818-94db-ffed45934bf5.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_45dbdb0d-96cc-49ba-86e5-6f10c0a0ef93.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_23be6e49-7cc3-4a30-9be6-3981288718da.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_72298236-d401-446c-b9a9-57e3d0499600.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_b5a849d1-d916-462d-8f63-3e961ff2ad36.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_f6545dca-6fec-4731-9910-9a399fdfa0b7.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_836b833e-e006-42ba-8b84-dacec198c5f8.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_9222faeb-7fa5-44bb-86fb-70cf4e24c6f3.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_cfd13204-dbe2-48e6-95ac-fc5559e9ef16.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_4e9a34a0-ee82-4b2b-9c82-8335efc9ddd1.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_3435a2ca-3838-4c05-a6bf-6ad35914e2f4.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_d0d02c67-40ee-4fb6-b617-11f23dfc416a.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_8f1cbcb4-8f26-48e0-913e-ff4d8a472cf4.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_e6ea6e56-e614-401a-8f1f-21ba01770f57.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_d79fdbf4-2296-459d-a6ab-33b7f4f55802.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_e7be17e7-e5f5-44e1-a373-a2ef3e7415a3.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_c3b2568f-3993-4d74-8858-84da6e2f5c80.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_cbc1f3f7-62cf-45df-be5b-98467de7b3ab.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_d5d678ac-7b14-4932-bd84-32bc537f3c1b.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_ccbfe2cd-391d-4302-96f7-89b2f868f4e8.h5',
#  '../../../../Desktop/v2/Harmonic/90.0deg/out_fc91389b-30ee-4597-aa86-76a4887fcb72.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_cbc54bab-5d19-46fe-8f88-f6bcb895548a.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_81d6c151-43be-4b9b-962a-4d397932717a.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_0fd81636-ec8a-43fe-8373-340eb76076b1.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_4f125a35-b558-495b-81b3-cab67ca9eb20.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_70cfd198-eefc-42a3-a45a-ed4b423e4dbb.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_16db0081-2efa-4912-9046-3ccfbb07d884.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_71529196-d892-4d8d-b3b7-335a4974be06.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_2fba0a79-1a88-4967-abba-44b0cb260e33.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_bd9009b3-2727-4d9b-b259-9ed82ec8d74a.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_54cfef08-da1b-47c0-8750-9e011bcba79a.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_301382db-03d5-4215-95a0-5b277a741c47.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_86a3ee15-5154-4f5c-a4ac-9eb256a5a394.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_2c0fdafd-ad5c-4f51-8568-336555fbaeb9.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_caae3973-b2fe-4bc0-8743-677a1b7cf661.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_fe085255-bc96-4f10-b7d0-96575534bea0.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_d22386c2-dc07-477d-b015-a4c3b5559dce.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_0c7fdf39-0ea3-4c84-9a9d-60c68b480bb1.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_d824d374-54dc-4a35-9b42-aca69ed69498.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_528c544e-cb83-4d42-b64f-ee646f430cb4.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_dbe7fbe6-e12c-472d-ab2f-3a0a143622fc.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_e884654d-45c7-48f2-aa0d-bc5182047cfb.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_76e7707e-3ca4-474a-9fca-7e96c90dcd6e.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_b3097349-7341-458e-bcf2-e69760f07458.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_3c2d3ca8-06b4-4cd6-b196-66127aa1f159.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_e7a6be34-8880-4a6f-a42e-65b6cf31f59b.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_581072d8-54b4-4e9e-bd06-e60879bd2df0.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_98bd1426-fe5c-4854-baa4-31d5b5f8d783.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_79271d9e-4b78-4818-8dc4-0aee2c70103b.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_54081af4-2898-44d7-997b-162655f33a81.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_b26bb895-5cc7-423a-be42-fb800a8ece85.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_8389bacd-2bfd-47c7-938b-74f33f0237f0.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_f143fb69-c297-404a-9025-1757263064af.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_ad8e4132-d3bb-4c33-b3e2-7fbdf929b2f8.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_a2ce998d-9d2b-490a-9c3c-ed5712916528.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_2832005d-7557-454b-8260-bf37cb6a998a.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_8bfe187d-867e-4a15-ab67-53b66bbe6b86.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_55baeb1d-1372-4bea-8cb1-f8e4d59815e9.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_ead50a5d-5541-49ac-8282-2469a074bc33.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_63cd663f-58bc-4542-b200-12094e47c5b2.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_f93aa404-051f-440e-bacd-70b22fc2c2f6.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_820b2262-fcad-444a-8a6d-8717d42cbc90.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_ab6edaa4-8c6a-43ed-9134-d24a4445c07a.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_c410d099-f514-467b-92d4-f4e83780f840.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_a2af910d-94a9-4fd6-8227-8421a29cc83b.h5',
#  '../../../../Desktop/v2/Harmonic/87.5deg/out_b3ffa1fe-fdde-4c59-9325-9b9fc4c400bd.h5',
# ...
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_63df0e31-4402-480f-b8cf-c2b181db1968.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_7b2de799-94ec-47cd-82b9-cb3683d6ca2f.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_bbf19027-28fd-4f38-812d-84cb24667094.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_8c4a9ce8-d1de-48c9-8275-303652fdf6b3.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_9ae46477-92de-42bc-b64f-f9e7854ccb46.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_9cecd232-56b7-4523-a6b3-c858bae16562.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_1f799c5e-076b-4a87-b85a-c5906c46e813.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_25eb5703-b320-4ba2-8fa1-c6b5710592ea.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_c4a58660-692a-41f9-953b-0c79da50fff3.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_77540d53-ad33-4dc0-9a7c-c6dfc359f2b9.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_f3ce1cd3-8635-490b-b9c8-e879404ff6b3.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_0b19bcee-cf7e-43b2-a6ef-e2400fb9794c.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_dca76dfa-ba4b-483e-8578-b1f33f659f12.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_19ee09d1-7dc3-4ab0-81c7-fc7a3714e29c.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_bf673a72-ec9e-4b0b-9171-1ac0a8d600a6.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_22d7b918-9d0d-4d18-a151-59cccb904101.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_26bf126d-9648-434f-84d6-76a99c419ca2.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_05e77000-bf5e-40af-9c20-d8ddd88dc6f9.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_842b0726-34ec-424c-ae9f-aa77eaf6fe8b.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_c0de4b37-fff3-47c6-bef8-31c91ab65159.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_bca2a4a7-763f-416d-acf3-62d4c5af56eb.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_beff4c52-5576-49a3-897a-91e63c61a8d2.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_f1202d09-34fa-4f20-b2fb-83ff91929264.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_3a750b73-f075-4150-99f5-2f0d166dc2af.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_fc631ddb-d234-4640-89a4-8037ff2010ac.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_97faf2cc-fa37-48ea-a0c8-2690ad54b2c2.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_cc5f66d0-1c46-4296-9208-59231d606b3b.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_65fd3706-d010-4a9c-b456-36140c686938.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_52dd2545-4167-406f-821b-9f07ab038c39.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_2611b9fc-eb49-4b2d-a1b1-c9c644980a7e.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_64819366-d35c-4a29-b4e9-73f2249b7d41.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_8b6ef98b-5415-4031-b10d-b77630f66d27.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_7dc4c4d5-86d1-4b4c-ac9a-1872cec5ef81.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_45e1a887-ddea-4c15-8ae0-68991639e2ff.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_0e673a21-a928-4942-a7cf-52a74b5e788a.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_86b606ec-5df9-4fbe-85f5-52ec535c2f06.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_9b95c6d1-3610-4450-b475-9ae0d5077690.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_c0724d4e-258d-4dc8-a37e-908793218457.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_f7133685-5b88-429d-bb10-c144e712cdef.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_f38ae7cc-ce72-4b94-8afd-9c0819f8ab96.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_42876807-d5fd-4bb4-b3af-d39208d51654.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_c15cb3f2-aee3-4f4e-aa21-6da88ce22b35.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_29f1362b-956d-4262-a196-6ab503f7a1bc.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_0f264a4e-2f4f-4814-b710-42c1247a2cc0.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_c4f18b31-fced-412b-9e39-643502188d48.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_cd799053-4b18-48d5-9ef7-7743d09d359e.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_61c0b7d2-643e-4653-9b25-8ec096bd324c.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_6a5faf8d-c56e-4dd6-b66f-0efa9df2a714.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_443bdb84-12ef-4aef-a6d3-a7f573b59573.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_2a2d0ac1-689b-4041-9616-0d6aab711e98.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_b566fcdf-9c6e-4cf8-9509-5db8c4af25bb.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_c43a9e04-2c4e-459e-852c-039a7d4ca975.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_f428840f-eaf4-47a5-aef2-918560a7adfb.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_45e8db83-93e1-4de7-a06e-e230b69ca1d7.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_89d87b34-675b-4c96-afd7-ad95c0873a6c.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_074a1d3e-b3ce-4582-b6a8-b04af51f9fe0.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_3ad7b5a6-9c16-4be9-84bc-024bb18fbc6d.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_8e85b40c-cc44-4b28-8ecc-a785b1d3ced5.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_708bee9d-9eb5-4f52-8c00-be68eac76078.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_bb69ed37-8053-4411-96e5-d38dbad4dec8.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_9ec97812-1eb4-47e0-81e2-cdfdda7fd21d.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_51fb6e9e-f55c-48f6-93b0-efab02a55606.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_338aa3c9-25f6-470f-a205-3b1bb213dabd.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_a6c21a07-5309-4e03-ae1f-24f33b5fed1f.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_b8cd088d-c860-4d14-b7d0-e78603bd9e1e.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_effe276e-406a-4bee-8352-610812867cfe.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_568b1dd2-d0f6-4e39-9c2c-1e8ee946f382.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/89.5deg/out_9eb33a6b-3c10-4d49-94ff-f04682bbbd14.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_d0c7f25d-11b0-4f98-a2b8-a1c00f90f9fe.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_a4bc7205-800a-443f-998c-95ab79556048.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_8eb4635b-4178-467c-9156-dba1887225bc.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_ef555c72-e434-41f9-adff-d66e916ea26c.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_ee1249fa-0631-45f1-a618-dd2139828dbc.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_738c9fb9-9417-442e-929a-3dddf5e9c01b.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_952c305b-ed67-4fe9-b584-2ec887af4b21.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_704e050e-a0d0-427f-8b39-43028c8f28ab.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_b2c1e544-db5f-4f31-b042-be9f7cd82ff4.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_8bd29bb7-82b1-4c5a-b2b5-f70a4485237c.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_4c84e554-cb5a-4ba2-84d4-71ae0bc02824.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_387a3e8e-9fab-4861-a26c-6677b4bc5c07.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_6ebffef4-2774-4c72-878b-e5b39015643d.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_f54ae368-0821-4dd4-9ff4-b8ff912ad807.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_b6baaaea-51dd-4e23-9105-ad34994f5888.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_96ae0e34-512b-4393-95d3-fc320a9b8027.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_5e3e59fe-6e73-4a98-9500-a2b78159b182.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_20acf3b6-96af-4425-8014-d01be271ef3b.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_7011d418-283f-49be-a180-7617350f3f88.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_b7dce26b-2dbc-4a15-a285-7d141f8ba070.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_12ce6d6a-2575-4ce6-8424-dcb5ac21d4dc.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_0f6ed307-b47c-410f-a4cf-b339db0284fc.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_94bf2fa7-28c6-4b73-91f6-a87e4c23d7b5.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_b97d1572-0427-4ca0-a79c-950cb91f3bec.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_1a4cea5d-c7e1-48ea-bfcf-11b4be31252a.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_f32d6d14-d274-4e70-bbe9-b1e37d5ea826.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_e8f0c862-d736-42ac-9eb7-1e8546f0152f.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_9a254a16-1838-4d2c-9584-645bcfe2986f.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_1311bfed-ff46-4ddc-8fe6-45756b6112b7.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_b4e76f56-9f6b-475c-b951-5dc259a7fb92.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_c6f54767-638b-4176-936e-0f9f338bc1f9.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_1b7a8561-48b2-4a28-81cb-0e7cf94f326b.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_e20360cc-7398-42f8-b859-ae05ecb5b129.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_5f4be760-df2c-4d23-877b-4048fe4d5b4b.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_81bea537-71de-41c2-8b68-65e5eefa6478.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_13002b88-64a6-4ed1-8e0c-22fbd8352b7f.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_f17e0a8b-6302-42c4-a302-b72a2adddd18.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_cf2d39fe-5c97-4c92-b1c7-0624a7331325.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_9341ebcc-d04b-4911-97cb-6df62fbe87c3.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_24665cb9-c450-4ce5-8bcd-6891f3982f2b.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_eb19a047-5551-4a32-bf41-7d7a6fa1c37d.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_ae797672-9ff7-4772-8e3a-599ecaceed34.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_f323fb38-c183-42c0-a1ad-fdc0b3494e9b.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_23f303aa-9dfc-47a9-9ae1-52f1cb9138ae.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_44f25bba-7d66-4938-a99a-c87d2fdd6fc4.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_9be41ca1-b870-4ec6-8abc-7a33b1117417.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_27f34c40-839c-4ba7-a04f-9e96c7d15d29.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_1bb426b8-c05d-4c37-811e-a72c133b1960.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_774a212d-e7f1-4458-9cf9-4d3916e5ccb6.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_b7828ff0-d249-44dc-bd4d-02729d1f6938.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_f7130d8b-38b5-4e4d-84e1-6e16a1dbc50a.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_43c7b905-f0d8-45af-87d8-bc789cc5d554.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_864d51d0-0f08-46ea-b74f-ef0b63dbc1eb.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_22c5d1ce-1a4b-417d-83d8-02cd422edea1.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_088d5762-6165-454c-89d8-ea2a84ce141e.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_52978d6b-2b9f-48d6-bf78-813d71d5b76b.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_5e2daec2-0d75-4e1a-8237-3d3a7e1500df.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_121f69eb-619a-4661-ae8b-da58bdbb7077.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_cb3850c8-9458-4f14-8d83-2f61d6b943b8.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_2ba08848-2e19-488c-96d8-28c737b637d2.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_8b983a5a-5d0b-47fb-aec7-d66bc2c798ef.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_a3e11fc2-7e45-4620-b6e2-54a7c872ccdd.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_8152b2b8-d09e-4757-9f1b-2a222a5b86fb.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_9d9bfc8c-2cb0-4b95-96b5-ad817cd96bba.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_5696d912-706f-40f7-865c-52766adc1b61.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_69f3f72c-8392-4cf2-b823-1f0c26434c62.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_23530980-01a6-4bb5-a4d4-3e0d4ec3c3cf.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_7082f3cb-002f-4a4a-8f4a-8885dbc0e23a.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_28293bc7-90bd-4b95-ac63-a78b3d5dad24.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_e5d0f3f1-6b73-4752-84c8-ce224ae90de6.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_a279cb7c-3f9a-410a-b6d9-4c43e76f9c08.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_6199c7f2-96e1-4d42-a0af-360a510ae722.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_b9846a12-d5cc-45f4-a008-1893c790c92a.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_508234e3-79b3-48e1-b4c3-738109bb104a.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_584cdb2e-4ff4-4f24-96a6-9c547ff9e8f2.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_7837573d-4752-49dc-ab7a-cbbff7e1112c.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_2f60cb3c-9970-4c0d-a5ae-ba8ec0e164ea.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_2b2aabdf-6862-4037-afbe-7b6b8b11f798.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_c41eba60-92b0-4266-ae62-a777f5792509.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_2a858034-b72f-4342-a72e-275bbbe74292.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_d070d08a-d2bf-448a-b48f-1d13305ebd41.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_1506c0ac-0382-49be-b909-b99c55814fa7.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_8b5e78f7-b879-427d-91d6-30f82a03f017.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_9a76fc3f-2eef-4590-bccd-27eca4690bf3.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_06b33e60-8526-45aa-800a-29d2b74fdb78.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_fcbd65b2-a657-4ead-bccc-120adf5caa9b.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_10a0dfef-44db-4ba0-a16b-6788ecbc7760.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_1cb10aea-e0b6-40fc-a216-d334a3171987.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_3503baa7-0581-40c5-8194-dce5f687e246.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_8096c6fe-0205-4dc2-9fa9-8781105032c8.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_b6ca7bf0-b2c4-48bf-a750-0ea4595b1a45.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_b4fc5b88-f69e-4e48-96ec-d5a26721872f.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_9e892dd6-e7dc-4bbc-9ee2-b8c31094d9f4.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_d7724e46-e305-4f82-85e3-30c8ff5a7e83.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_223a902b-c971-419d-b083-081e590d6d86.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_b5952493-8457-46b4-a99f-5b638ac642a0.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_8fd2e7cf-2ef0-4439-8b70-dd2dab24dac5.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_46cf40e9-6679-4903-bb00-11f6fb4689b2.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_23987774-c145-44d7-b14e-ce7104847ec6.h5',
#  '../../../../Desktop/1Tesla/v1/Harmonic/88.0deg/out_8d39fe07-2442-47d1-a8f2-2622c242a913.h5',
#  ...]
